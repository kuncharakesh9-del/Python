# %%
age_list  = [24,25,26,27,28]
print(age_list)
name_list = ["Python", "Excel", "PowerBI","Panda","SQL"]
print(name_list)
name_list.append("Yazhini")
print(name_list)
age_list.insert(2,30)
print(age_list)
name_list.remove("Yazhini")
print(name_list)
print(age_list.pop())
age_list.extend([29, 30, 26])
print(age_list)
age_list.sort(reverse=True)
print(age_list)
print(max(age_list))
print(min(age_list))
print(sum(age_list))
first= name_list[0]
print(first)
Last= name_list[-1]
print(Last)
Index= name_list[2:4]
print(Index)
print(name_list[::-1])
# Out:
# [24, 25, 26, 27, 28]
# ['Python', 'Excel', 'PowerBI', 'Panda', 'SQL']
# ['Python', 'Excel', 'PowerBI', 'Panda', 'SQL', 'Yazhini']
# [24, 25, 30, 26, 27, 28]
# ['Python', 'Excel', 'PowerBI', 'Panda', 'SQL']
# 28
# [24, 25, 30, 26, 27, 29, 30, 26]
# [30, 30, 29, 27, 26, 26, 25, 24]
# 30
# 24
# 217
# Python
# SQL
# ['PowerBI', 'Panda']
# ['SQL', 'Panda', 'PowerBI', 'Excel', 'Python']

# %%
student_marks = {"Rakesh": 75, "Rahul": 88, "Suresh": 92, "Priya": 79, "Anjali": 85}
print(student_marks)

print(student_marks["Rahul"])

student_marks["Janani"]=80
print(student_marks)

student_marks["Rakesh"]=82
print(student_marks)

print(student_marks.keys())
print(student_marks.values())
print(student_marks.items())
# Out:
# {'Rakesh': 75, 'Rahul': 88, 'Suresh': 92, 'Priya': 79, 'Anjali': 85}
# 88
# {'Rakesh': 75, 'Rahul': 88, 'Suresh': 92, 'Priya': 79, 'Anjali': 85, 'Janani': 80}
# {'Rakesh': 82, 'Rahul': 88, 'Suresh': 92, 'Priya': 79, 'Anjali': 85, 'Janani': 80}
# dict_keys(['Rakesh', 'Rahul', 'Suresh', 'Priya', 'Anjali', 'Janani'])
# dict_values([82, 88, 92, 79, 85, 80])
# dict_items([('Rakesh', 82), ('Rahul', 88), ('Suresh', 92), ('Priya', 79), ('Anjali', 85), ('Janani', 80)])

# %%
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}
print(my_set)

my_set[4] = 's'

set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}
print("Set 1:", set1)
print("Set 2:", set2)

union_set = set1.union(set2)
print("Union:", union_set)

intersection_set = set1.intersection(set2)
print("Intersection:", intersection_set)
# Out:
# {'e', 'u', 'o', 'i', 'a'}
# Set 1: {1, 3, 5, 7, 9}
# Set 2: {2, 3, 5, 8, 10}
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %%
score = float(input("Enter your score (0 to 10): "))
if score<0 or score >10:
    print("Invalid score, please enter value between the 0 or 10")
    
elif score >7:
    print("Above Avg")
    
elif score>=4
    print ("Avg")
    
elif score<4:
    print("Below Avg")
    
else:
    print("Need to Improve your performance consistent practice will lead to better results")
# Out:
# Enter your score (0 to 10):  10
# Above Avg
